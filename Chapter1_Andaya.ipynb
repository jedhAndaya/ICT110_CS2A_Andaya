# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
x = 7
print(x)
# Out:
# 7

# %% [markdown]
# Exercise 1

# %%
print('Hello World!')
#the letter "P" command "print" is in capital letter so i change it into small case.
# Out:
# Hello World

# %%
print('Hello wolrd!')
#The mistake here is that there is a missing open parenthesis.
#So the solution is that i put the missing open parenthesis.
# Out:
# Hello wolrd!

# %%
print('Hello World')
#The missing is single closing quotation and the solution is i put the missing single closing quotation.
# Out:
# Hello World

# %%
print('Hello World!')
#the error here is that the single quotation happens to be three so i remove the another quotation to correct the error.
# Out:
# Hello World!

# %% [markdown]
# Exercise 2

# %%
x = 43
x= x + 1
print(x)

#the answer is "44" because x is 43 stored on the variable of x and then we create another code that add another 1 so the calculated answer is "44"
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = x + 1
print(x)
#the error on this code is in the code line 2 "x = X +1" because in "x = X + 1" the variable is in capital letter, so i change the variable into small letter.
# Out:
# 44

# %% [markdown]
# Chapter 2

# %%
name = input("Enter your name: ")
print('welcome', name)
# Out:
# Enter your name: jedh
# welcome jedh

# %%
entH = float(input("Enter Hours: "))
etR = float(input("Enter per rate: "))
total = entH * etR
print("Total pay: ", total)
# Out:
# Enter Hours: 35
# Enter per rate: 2.75
# Total pay:  96.25
